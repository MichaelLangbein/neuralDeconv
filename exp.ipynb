# %% [markdown]
# # Utils
#
#  - download data from sentinelhub
#  - get shapefile
#  - convert shapefile to raster

# %%
import data as d
import matplotlib.pyplot as plt

# %%
ds = d.getLksRasterioDataset(800, 800)

# %%
plt.imshow(ds.read(1))

# %%
win = d.getWindowFromRasterioDataset(7, 47, 14, 52, ds)

# %%
plt.imshow(win[0])
